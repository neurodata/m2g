# %% [markdown]
# # import packages

# %%
# -*- coding: utf-8 -*-
import warnings

warnings.simplefilter("ignore")
import sys
import nibabel as nib
import numpy as np
import nilearn.image as nl
import os
from PIL import Image, ImageDraw,ImageFont
import matplotlib.pyplot as plt
import sys
sys.path.append(r'F:\JHU\ndd\ndmg\ndmg\stats')
from qa_skullstrip import gen_overlay_pngs
# Out:
# C:\Users\luochuankai\Anaconda3\lib\site-packages\sklearn\externals\joblib\__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# # run qa_skullstrip.py

# %%
## the image result will be save at outdir  = r'F:/JHU/ndd/dataset/output1/sub-0025864/ses-1/'

# %%
# %matplotlib inline
origional = r'F:/JHU/ndd/dataset/part_of_SWU4/sub-0025629_ses-1_T1w.nii.gz'
brain = r'C:/Users/luochuankai/Desktop/trash/skulled/sub-0025629_ses-1_T1w_noskull.nii.gz'
outdir  = r'F:/JHU/ndd/dataset/output1/sub-0025864/ses-1/'
gen_overlay_pngs(brain, origional,outdir, loc=0, mean=False, minthr=2, maxthr=95, edge=False)
