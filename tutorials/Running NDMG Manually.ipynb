# %%
import os
import os.path as op
import glob
from pathlib2 import Path
from ndmg.scripts import ndmg_dwi_pipeline
from ndmg.utils import s3_utils

# %%
# Download test data
data_dir = op.expanduser("~") + "/.ndmg"
if not op.isdir(data_dir):
    os.mkdirs(data_dir)
s3_utils.s3_get_data('ndmg-data', 'HNU1t', data_dir)

# Specify base directory and paths to input files (dwi, bvecs, bvals, and t1w required)
t1w = data_dir + '/sub-0025427/ses-1/anat/sub-0025427_ses-1_T1w.nii.gz'
bvals = data_dir + '/sub-0025427/ses-1/dwi/sub-0025427_ses-1_dwi.bval'
bvecs = data_dir + '/sub-0025427/ses-1/dwi/sub-0025427_ses-1_dwi.bvec'
dwi = data_dir + '/sub-0025427/ses-1/dwi/sub-0025427_ses-1_dwi.nii.gz'

###USER-SPECIFIED PARAMETERS###
# Specify NDMG run parameters
## CHOICES:
## atlases = ['desikan', 'CPAC200', 'DKT', 'HarvardOxfordcort', 'HarvardOxfordsub', 'JHU', 'Schaefer2018-200', 'Talairach', 'aal', 'brodmann', 'glasser', 'yeo-7-liberal', 'yeo-17-liberal']
## mod_types = ['det', 'prob']
## track_types = ['local', 'particle']
## mods = ['csa', 'csd']
## regs = ['native', 'native_dsn', 'mni']
## vox_size = ['1mm', '2mm']

# Select an atlas
atlas = 'desikan'
mod_type = 'det'
track_type = 'local'
mod_func = 'csd'
reg_style = 'native'
vox_size = '2mm'

# Set an output directory
outdir = '/tmp/output_{}_{}_{}_{}_{}'.format(atlas, mod_type, track_type, mod_func, reg_style)
###############################
# Download neuroparc files
atlas_dir = op.expanduser("~") + "/.ndmg/ndmg_atlases"
    
# Auto-set paths to neuroparc files
mask = str(Path.home()) + '/.ndmg/ndmg_atlases/atlases/mask/MNI152NLin6_res-2x2x2_T1w_descr-brainmask.nii.gz'
labels = [i for i in glob.glob(str(Path.home()) + '/.ndmg/ndmg_atlases/atlases/label/Human/*2x2x2.nii.gz') if atlas in i]

# Run pipeline
ndmg_dwi_pipeline.ndmg_dwi_worker(dwi, bvals, bvecs, t1w, atlas, mask, labels, outdir, vox_size, mod_type, track_type, mod_func, reg_style, clean=False, skipeddy=False)
# Out:
# dwi = /Users/derekpisner/Applications/ndmg/tests/data/BNU1/sub-0025864/ses-1/dwi/sub-0025864_ses-1_dwi.nii.gz
# bvals = /Users/derekpisner/Applications/ndmg/tests/data/BNU1/sub-0025864/ses-1/dwi/sub-0025864_ses-1_dwi.bval
# bvecs = /Users/derekpisner/Applications/ndmg/tests/data/BNU1/sub-0025864/ses-1/dwi/sub-0025864_ses-1_dwi.bvec
# t1w = /Users/derekpisner/Applications/ndmg/tests/data/BNU1/sub-0025864/ses-1/anat/sub-0025864_ses-1_T1w.nii.gz
# atlas = desikan
# mask = /Users/derekpisner/.ndmg/ndmg_atlases/atlases/mask/MNI152NLin6_res-2x2x2_T1w_descr-brainmask.nii.gz
# labels = ['/Users/derekpisner/.ndmg/ndmg_atlases/atlases/label/Human/desikan_space-MNI152NLin6_res-2x2x2.nii.gz']
# outdir = /tmp/output_desikan_det_local_csd_native
# vox_size = 2mm
# mod_type = det
# track_type = local
# mod_func = csd
# reg_style = native
# clean = False
# skip eddy = False
# Output directory: /tmp/output_desikan_det_local_csd_native
# Adding directory tree...
# Connectomes downsampled to given labels: /tmp/output_desikan_det_local_csd_native/dwi/roi-connectomes/desikan_space-MNI152NLin6_res-2x2x2/sub-0025864_ses-1_dwi_desikan_space-MNI152NLin6_res-2x2x2_measure-spatial-ds_adj.ssv
# Pre-existing preprocessed dwi files found. Deleting these...
# Performing eddy correction...
# eddy_correct /Users/derekpisner/Applications/ndmg/tests/data/BNU1/sub-0025864/ses-1/dwi/sub-0025864_ses-1_dwi.nii.gz /tmp/output_desikan_det_local_csd_native/dwi/preproc/eddy_corrected_data.nii.gz 0
# Rescaling b-vectors...
# Reorienting /tmp/output_desikan_det_local_csd_native/dwi/preproc/eddy_corrected_data.nii.gz to RAS+...
# Reorienting runtime: 1.8s
# Reslicing image /tmp/output_desikan_det_local_csd_native/dwi/preproc/eddy_corrected_data_reor_RAS.nii.gz to 2mm...
# Reslicing runtime: 21.4s
# fbval:  /tmp/output_desikan_det_local_csd_native/dwi/preproc/bval.bval
# bvecs:  /tmp/output_desikan_det_local_csd_native/dwi/preproc/bvecs_reor.bvec
# fbvec:  /tmp/output_desikan_det_local_csd_native/dwi/preproc/bvec.bvec
# dwi_prep:  /tmp/output_desikan_det_local_csd_native/dwi/preproc/eddy_corrected_data_reor_RAS_res.nii.gz
# namer.dirs:  /tmp/output_desikan_det_local_csd_native/dwi/preproc
# /tmp/output_desikan_det_local_csd_native/dwi/preproc/bval.bval
# /tmp/output_desikan_det_local_csd_native/dwi/preproc/bvec.bvec
# B0's found at: [0]
# B-values shape (31,)
#          min 0.000000
#          max 1000.000000
# B-vectors shape (31, 3)
#          min -0.978756
#          max 0.979329
# None
# Extracting B0's...
# 0
# fslroi /tmp/output_desikan_det_local_csd_native/dwi/preproc/eddy_corrected_data_reor_RAS_res.nii.gz /tmp/output_desikan_det_local_csd_native/dwi/preproc/0_B0.nii.gz 0 1
# Preprocessing runtime: 28.7s
# Pre-existing preprocessed t1w files found. Deleting these...
# Pre-existing registered t1w files found. Deleting these...
# Pre-existing temporary files found. Deleting these...
# Reorienting /Users/derekpisner/Applications/ndmg/tests/data/BNU1/sub-0025864/ses-1/anat/sub-0025864_ses-1_T1w.nii.gz to RAS+...
# Reslicing image /tmp/output_desikan_det_local_csd_native/anat/preproc/sub-0025864_ses-1_T1w_reor_RAS.nii.gz to 2mm...
# Reorienting runtime: 1.5s
# Running tractography in native space...
# Extracting brain from raw T1w image...
# Executing: 3dSkullStrip -prefix /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain.nii.gz -input /tmp/output_desikan_det_local_csd_native/anat/preproc/sub-0025864_ses-1_T1w_reor_RAS_res.nii.gz
# Segmenting Anatomical Image into WM, GM, and CSF with FSL's FAST:
# Executing fast: fast -t 1  -n 3 -o /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_seg /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain.nii.gz
# Reslicing image /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain.nii.gz to 2mm...
# Reslicing image /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_seg_pve_2.nii.gz to 2mm...
# Reslicing image /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_seg_pve_1.nii.gz to 2mm...
# Reslicing image /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_seg_pve_0.nii.gz to 2mm...
# fslmaths /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_wm_thr.nii.gz -edge -bin -mas /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_wm_thr.nii.gz /tmp/output_desikan_det_local_csd_native/tmp/reg_a/t1w_wm_edge.nii.gz
# gen_tissue runtime: 188.1s
# flirt -in /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain_nores.nii.gz -ref /usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -omat /tmp/output_desikan_det_local_csd_native/tmp/reg_m/xfm_t1w2mni_init.mat -dof 12 -interp spline -cost mutualinfo -searchrx -180 180 -searchry -180 180 -searchrz -180 180
# Running non-linear registration: T1w-->MNI ...
# fnirt --in=/tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain_nores.nii.gz --ref=/usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz --aff=/tmp/output_desikan_det_local_csd_native/tmp/reg_m/xfm_t1w2mni_init.mat --iout=/tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_aligned_mni.nii.gz --cout=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/warp_t12mni.nii.gz --warpres=8,8,8 --refmask=/usr/local/fsl/data/standard/MNI152_T1_2mm_brain_mask.nii.gz --applyrefmask=1 --config=/usr/local/fsl/etc/flirtsch/T1_2_MNI152_2mm.cnf
# invwarp --warp=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/warp_t12mni.nii.gz --out=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/mni2t1w_warp.nii.gz --ref=/tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain_nores.nii.gz
# convert_xfm -omat /tmp/output_desikan_det_local_csd_native/tmp/reg_m/xfm_mni2t1w_init.mat -inverse /tmp/output_desikan_det_local_csd_native/tmp/reg_m/xfm_t1w2mni_init.mat
# flirt -in /tmp/output_desikan_det_local_csd_native/dwi/preproc/nodif_B0.nii.gz -ref /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain_nores.nii.gz -omat /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1w2dwi_xfm.mat -dof 6 -interp spline -cost mutualinfo -searchrx -180 180 -searchry -180 180 -searchrz -180 180
# convert_xfm -omat /tmp/output_desikan_det_local_csd_native/tmp/reg_m/dwi2t1w_xfm.mat -inverse /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1w2dwi_xfm.mat
# Running FLIRT BBR registration: T1w-->DWI ...
# flirt -in /tmp/output_desikan_det_local_csd_native/dwi/preproc/nodif_B0.nii.gz -ref /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain_nores.nii.gz -omat /tmp/output_desikan_det_local_csd_native/tmp/reg_m/dwi2t1w_bbr_xfm.mat -dof 7 -bins 256 -interp spline -cost bbr -searchrx -180 180 -searchry -180 180 -searchrz -180 180 -schedule ${FSLDIR}/etc/flirtsch/bbr.sch -wmseg /tmp/output_desikan_det_local_csd_native/tmp/reg_a/t1w_wm_edge.nii.gz -init /tmp/output_desikan_det_local_csd_native/tmp/reg_m/dwi2t1w_xfm.mat
# flirt -in /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain_nores.nii.gz -ref /tmp/output_desikan_det_local_csd_native/dwi/preproc/nodif_B0.nii.gz -omat /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1wtissue2dwi_xfm.mat -out /tmp/output_desikan_det_local_csd_native/anat/registered/t1w_in_dwi.nii.gz -dof 7 -interp spline -cost mutualinfo -searchrx -180 180 -searchry -180 180 -searchrz -180 180 -init /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1w2dwi_bbr_xfm.mat
# t1w2dwi_align runtime: 663.7s
# Creating MNI-space ventricle ROI...
# flirt -in /usr/local/fsl/data/atlases/HarvardOxford/HarvardOxford-sub-prob-2mm.nii.gz -ref /usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -omat /tmp/output_desikan_det_local_csd_native/tmp/reg_m/roi_2_mni.mat -dof 6 -interp spline -cost mutualinfo -searchrx -180 180 -searchry -180 180 -searchrz -180 180
# flirt -in /tmp/output_desikan_det_local_csd_native/tmp/reg_a/VentricleMask.nii.gz -ref /usr/local/fsl/data/standard/MNI152_T1_2mm_brain.nii.gz -out /tmp/output_desikan_det_local_csd_native/tmp/reg_a/vent_mask_mni.nii.gz -init /tmp/output_desikan_det_local_csd_native/tmp/reg_m/roi_2_mni.mat -interp trilinear -dof 6 -applyxfm
# applywarp --ref=/tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain_nores.nii.gz --in=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/vent_mask_mni.nii.gz --out=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/vent_mask_t1w.nii.gz --warp=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/mni2t1w_warp.nii.gz --interp=nn --super --superlevel=a
# flirt -in /tmp/output_desikan_det_local_csd_native/tmp/reg_a/vent_mask_t1w.nii.gz -ref /tmp/output_desikan_det_local_csd_native/dwi/preproc/nodif_B0.nii.gz -out /tmp/output_desikan_det_local_csd_native/tmp/reg_a/t1w_vent_mask_dwi.nii.gz -init /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1wtissue2dwi_xfm.mat -interp trilinear -dof 6 -applyxfm
# flirt -in /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_seg_pve_0_nores.nii.gz -ref /tmp/output_desikan_det_local_csd_native/dwi/preproc/nodif_B0.nii.gz -out /tmp/output_desikan_det_local_csd_native/anat/registered/t1w_csf_mask_dwi.nii.gz -init /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1wtissue2dwi_xfm.mat -interp trilinear -dof 6 -applyxfm
# flirt -in /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_seg_pve_1_nores.nii.gz -ref /tmp/output_desikan_det_local_csd_native/dwi/preproc/nodif_B0.nii.gz -out /tmp/output_desikan_det_local_csd_native/anat/registered/t1w_gm_in_dwi.nii.gz -init /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1wtissue2dwi_xfm.mat -interp trilinear -dof 6 -applyxfm
# flirt -in /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_seg_pve_2_nores.nii.gz -ref /tmp/output_desikan_det_local_csd_native/dwi/preproc/nodif_B0.nii.gz -out /tmp/output_desikan_det_local_csd_native/anat/registered/t1w_wm_in_dwi.nii.gz -init /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1wtissue2dwi_xfm.mat -interp trilinear -dof 6 -applyxfm
# Creating ventricular CSF mask...
# tissue2dwi_align runtime: 198.2s
# Using 13689500 seeds...
# Beginning tractography...
# Fitting CSD model...
# Attempting to use spherical harmonic basis first...
# Obtaining peaks from model...
# Reconstructing tractogram streamlines...
# Streamlines complete
# Generating graph for /Users/derekpisner/.ndmg/ndmg_atlases/atlases/label/Human/desikan_space-MNI152NLin6_res-2x2x2.nii.gz parcellation...
# Applying native-space alignment to /Users/derekpisner/.ndmg/ndmg_atlases/atlases/label/Human/desikan_space-MNI152NLin6_res-2x2x2.nii.gz
# Reorienting /Users/derekpisner/.ndmg/ndmg_atlases/atlases/label/Human/desikan_space-MNI152NLin6_res-2x2x2.nii.gz to RAS+...
# Reslicing image /tmp/output_desikan_det_local_csd_native/anat/preproc/desikan_space-MNI152NLin6_res-2x2x2_reor_RAS.nii.gz to 2mm...
# flirt -in /tmp/output_desikan_det_local_csd_native/anat/preproc/desikan_space-MNI152NLin6_res-2x2x2_reor_RAS_nores.nii.gz -ref /tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_aligned_mni.nii.gz -out /tmp/output_desikan_det_local_csd_native/tmp/reg_a/desikan_space-MNI152NLin6_res-2x2x2_reor_RAS_nores_aligned_atlas_t1w_mni.nii.gz -dof 12 -bins 256 -interp nearestneighbour -cost mutualinfo -searchrx -180 180 -searchry -180 180 -searchrz -180 180
# applywarp --ref=/tmp/output_desikan_det_local_csd_native/anat/preproc/t1w_brain_nores.nii.gz --in=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/desikan_space-MNI152NLin6_res-2x2x2_reor_RAS_nores_aligned_atlas_t1w_mni.nii.gz --out=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/desikan_space-MNI152NLin6_res-2x2x2_reor_RAS_nores_aligned_atlas_skull.nii.gz --warp=/tmp/output_desikan_det_local_csd_native/tmp/reg_a/mni2t1w_warp.nii.gz --interp=nn --super --superlevel=a
# flirt -in /tmp/output_desikan_det_local_csd_native/tmp/reg_a/desikan_space-MNI152NLin6_res-2x2x2_reor_RAS_nores_aligned_atlas_skull.nii.gz -ref /tmp/output_desikan_det_local_csd_native/dwi/preproc/nodif_B0.nii.gz -out /tmp/output_desikan_det_local_csd_native/anat/registered/desikan_space-MNI152NLin6_res-2x2x2_reor_RAS_nores_aligned_atlas.nii.gz -dof 6 -bins 256 -interp nearestneighbour -cost mutualinfo -searchrx -180 180 -searchry -180 180 -searchrz -180 180 -init /tmp/output_desikan_det_local_csd_native/tmp/reg_m/t1wtissue2dwi_xfm.mat
# Building connectivity matrix...
# # of Streamlines: 554602
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-1b89788b0864> in <module>
#      33
#      34 # Run pipeline
# ---> 35 ndmg_dwi_pipeline.ndmg_dwi_worker(dwi, bvals, bvecs, t1w, atlas, mask, labels, outdir, vox_size, mod_type, track_type, mod_func, reg_style, clean=False, skipeddy=False)
#      36
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ndmg-0.1.3-py3.7.egg/ndmg/scripts/ndmg_dwi_pipeline.py in ndmg_dwi_worker(dwi, bvals, bvecs, t1w, atlas, mask, labels, outdir, vox_size, mod_type, track_type, mod_func, reg_style, clean, skipeddy, buck, remo, push, creds, debug, modif)
#     465                 connectome_path=connectomes[idx],
#     466             )
# --> 467             g1.make_graph()
#     468         elif reg_style == "mni":
#     469             labels_im_file = mgu.reorient_img(labels[idx], namer)
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ndmg-0.1.3-py3.7.egg/ndmg/graph/gen_graph.py in make_graph(self, error_margin, overlap_thr, voxel_size)
#     185
#     186             # get labels for label_volume
# --> 187             i, j, k = points.T
#     188             lab_arr = self.rois[1:][i, j, k]
#     189             endlabels = []
#
# ValueError: too many values to unpack (expected 3)
